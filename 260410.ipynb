# %%
i = 0
while i < 5:
    if i == 2:
        continue  # i가 2에서 증가하지 않아 계속 2에 머물 수 있음
    i += 1
    print(i)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2443/2683981201.py in <cell line: 0>()
#       2 while i < 5:
#       3     if i == 2:
# ----> 4         continue  # i가 2에서 증가하지 않아 계속 2에 머물 수 있음
#       5     i += 1
#       6     print(i)
#
# KeyboardInterrupt:

# %%
i = 0
while i < 5:
    i += 1
    if i == 2:
        continue  # 2는 건너뜀
    print(i)
# 출력: 1 3 4 5
# Out:
# 1
# 3
# 4
# 5

# %%
a = [10, 20, 30]
print(a[0])   # 10
a[1] = 99     # 수정 가능
# Out:
# 10

# %%
a
# Out:
# [10, 99, 30]

# %%
a[0]
# Out:
# 10

# %%
a[1]
# Out:
# 99

# %%
a[2]
# Out:
# 30

# %%
empty = []
nums = [1, 2, 3]
mixed = [1, "hello", True, [9, 8]]

# %%
mixed[1]
# Out:
# 'hello'

# %%
mixed[2]
# Out:
# True

# %%
mixed[3]
# Out:
# [9, 8]

# %%
empty
# Out:
# [4, 4, 4]

# %%
empty.append(1)

# %%
len(empty)
# Out:
# 3

# %%
sum(empty)
# Out:
# 12

# %%
min(empty)
# Out:
# 4

# %%
list(reversed(empty))
# Out:
# [4, 4, 4]

# %%
sorted(empty)
# Out:
# [1, 4, 4, 4, 6]

# %%
fruits = ["apple", "banana", "cherry"]

# %%
print(fruits[0])
# Out:
# apple

# %%
fruits.extend([
    "orange", "grape", "mango", "pineapple", "strawberry",
    "blueberry", "peach", "pear", "kiwi", "watermelon"
])

# %%
fruits
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  'orange',
#  'grape',
#  'mango',
#  'pineapple',
#  'strawberry',
#  'blueberry',
#  'peach',
#  'pear',
#  'kiwi',
#  'watermelon']

# %%
len(fruits)
# Out:
# 13

# %%
for i in range(13):
  print(fruits[i])
# Out:
# apple
# banana
# cherry
# orange
# grape
# mango
# pineapple
# strawberry
# blueberry
# peach
# pear
# kiwi
# watermelon

# %%
for a in fruits:
 print(a)
# Out:
# apple
# banana
# cherry
# orange
# grape
# mango
# pineapple
# strawberry
# blueberry
# peach
# pear
# kiwi
# watermelon

# %%
for a in "flower":
   print(a)
# Out:
# f
# l
# o
# w
# e
# r

# %%
upper_fruits = []
for fruit in fruits:
    upper_fruits.append(fruit.upper())

print(upper_fruits)
# Out:
# ['APPLE', 'BANANA', 'CHERRY', 'ORANGE', 'GRAPE', 'MANGO', 'PINEAPPLE', 'STRAWBERRY', 'BLUEBERRY', 'PEACH', 'PEAR', 'KIWI', 'WATERMELON']

# %%
long_fruits = []
for fruit in fruits:
    if len(fruit) >= 6:
        long_fruits.append(fruit)
print(long_fruits)
# Out:
# ['banana', 'cherry', 'orange', 'pineapple', 'strawberry', 'blueberry', 'watermelon']

# %%
for i, fruit in enumerate(fruits):
    i+=1
    print(i, fruit)

# 1 apple
# 2 banana
# 3 cherry
# Out:
# 1 apple
# 2 banana
# 3 cherry
# 4 orange
# 5 grape
# 6 mango
# 7 pineapple
# 8 strawberry
# 9 blueberry
# 10 peach
# 11 pear
# 12 kiwi
# 13 watermelon

# %%
joseon_kings = [
    "태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"
]

# %%
for i,k in enumerate(joseon_kings):
  i+=1
  print(f'{i}대왕 {k}')
# Out:
# 1대왕 태조
# 2대왕 정종
# 3대왕 태종
# 4대왕 세종
# 5대왕 문종
# 6대왕 단종
# 7대왕 세조
# 8대왕 예종
# 9대왕 성종
# 10대왕 연산군
# 11대왕 중종
# 12대왕 인종
# 13대왕 명종
# 14대왕 선조
# 15대왕 광해군
# 16대왕 인조
# 17대왕 효종
# 18대왕 현종
# 19대왕 숙종
# 20대왕 경종
# 21대왕 영조
# 22대왕 정조
# 23대왕 순조
# 24대왕 헌종
# 25대왕 철종
# 26대왕 고종
# 27대왕 순종

# %%
a= input("왕의 이름을 입력하시오.: ")
i=0
while a != joseon_kings[i]:
  i+=1
print(f'{i+1}대왕 {joseon_kings[i]}')
# Out:
# 왕의 이름을 입력하시오.: 세종
# 4대왕 세종

# %%
a= input("왕의 이름을 입력하시오.: ")
if a in joseon_kings:
  print(f"{joseon_kings.index(a)+1}대 왕 {a}")
else:
 print("존재하지 않는 왕입니다.")
# Out:
# 왕의 이름을 입력하시오.: 태종
# 3대 왕 태종

# %%
joseon_kings_reversed= []

# %%
joseon_kings_reversed = list(reversed(joseon_kings))
for i in joseon_kings_reversed:
  print(i)
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조

# %%
for i in range(len(joseon_kings)-1,-1,-1):
  print(joseon_kings[i])
# Out:
# 순종
# 고종
# 철종
# 헌종
# 순조
# 정조
# 영조
# 경종
# 숙종
# 현종
# 효종
# 인조
# 광해군
# 선조
# 명종
# 인종
# 중종
# 연산군
# 성종
# 예종
# 세조
# 단종
# 문종
# 세종
# 태종
# 정종
# 태조
